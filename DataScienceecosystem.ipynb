# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
# 1. Julia
# 2. R
# 3. Python

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. Pycharm
# 2. NumPy
# 3. Panda

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# |1. Tenserflow       |
# |2. Apaceh Spark     |
# |3. MongoDB          |

# %% [markdown]
# ### Below are a few example of evaluating arithematic expressions in Python

# %%
# This is arithematic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives :**
# - Learn about the various data science tools
# - Learn about the development environment in data science
# - Learn about the languages in data science like R, Python, Scala

# %% [markdown]
# ## Author
# Om Pandey
